# %% [markdown]
# # gen ssh

# %%
aistudio@jupyter-2563417-10053501:~$ ssh-keygen
Generating public/private rsa key pair.
Enter file in which to save the key (/home/aistudio/.ssh/id_rsa): 
Enter passphrase (empty for no passphrase): 
Enter same passphrase again: 
Your identification has been saved in /home/aistudio/.ssh/id_rsa
Your public key has been saved in /home/aistudio/.ssh/id_rsa.pub
The key fingerprint is:
SHA256:zT+UQrTFYg2U8cChIxCrjKGDdEpA2FR8D4igyNSFuNM aistudio@jupyter-2563417-10053501
The key's randomart image is:
+---[RSA 3072]----+
|=*++*+   oBB.    |
|B.ooooo  o==o    |
|++o....oo.o..    |
|=*oE   ..=   .   |
|=.+     S + o    |
| .         +     |
|            o    |
|             .   |
|                 |
+----[SHA256]-----+

# %%
Settings → SSH and GPG keys → New SSH key

# %%
ssh -T git@github.com
# defautl 22 port canot connect use 443

# %%
ssh -T -p 443 git@ssh.github.com

# %%
SSH 连接
   ↓
通过 443 端口
   ↓
伪装成 HTTPS 可通道
   ↓
到 GitHub SSH server

# %%
aistudio@jupyter-2563417-10053501:~$ ssh -T -p 443 git@ssh.github.com
The authenticity of host '[ssh.github.com]:443 ([20.205.243.160]:443)' can't be established.
ECDSA key fingerprint is SHA256:p2QAMXNIC1TJYWeIOttrVc98/R1BUFWu3/LiyKgUfQM.
Are you sure you want to continue connecting (yes/no/[fingerprint])?

# %%
aistudio@jupyter-2563417-10053501:~$ ssh -T -p 443 git@ssh.github.com
The authenticity of host '[ssh.github.com]:443 ([20.205.243.160]:443)' can't be established.
ECDSA key fingerprint is SHA256:p2QAMXNIC1TJYWeIOttrVc98/R1BUFWu3/LiyKgUfQM.
Are you sure you want to continue connecting (yes/no/[fingerprint])? y
Please type 'yes', 'no' or the fingerprint: yes
Warning: Permanently added '[ssh.github.com]:443,[20.205.243.160]:443' (ECDSA) to the list of known hosts.
Hi guoheidanqq! You've successfully authenticated, but GitHub does not provide shell access.
aistudio@jupyter-2563417-10053501:~$

# %%
vi ~/.ssh/config
i into insert mode
Host github.com
  HostName ssh.github.com
  User git
  Port 443

esc :wq

# %%
cp -r /home/aistudio/.ssh /home/aistudio/work/

# %%
cp -r /home/aistudio/work/.ssh/.  /home/aistudio/.ssh/
